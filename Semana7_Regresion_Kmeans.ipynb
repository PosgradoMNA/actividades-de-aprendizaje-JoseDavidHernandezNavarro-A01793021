# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-JoseDavidHernandezNavarro-A01793021/blob/main/Semana7_Regresion_Kmeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Models

# %% [markdown]
# # Ejercicio 1
#
# Utiliza la base de datos de
# https://www.kaggle.com/vinicius150987/manufacturing-cost
#
# Suponga que trabaja como consultor de una empresa de nueva creación que busca desarrollar un modelo para estimar el costo de los bienes vendidos a medida que varían el volumen de producción (número de unidades producidas). La startup recopiló datos y le pidió que desarrollara un modelo para predecir su costo frente a la cantidad de unidades vendidas.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.preprocessing import PolynomialFeatures

# %%
df = pd.read_csv('https://raw.githubusercontent.com/marypazrf/bdd/main/EconomiesOfScale.csv')
df.sample(10)
# Out:
#      Number of Units  Manufacturing Cost
# 832         5.656692           30.805364
# 595         4.781505           39.032405
# 318         3.870496           32.169557
# 107         2.840835           51.540917
# 610         4.855505           32.989285
# 374         4.077251           36.072628
# 543         4.583116           36.889849
# 332         3.925889           35.303587
# 850         5.780971           28.886753
# 19          1.767002           71.614173

# %% [markdown]
# ## 1.1 Divide los datos del costo de manufactura. Utiliza la función train_test_split (viene el ejemplo al final del notebook).

# %%
df.shape
# Out:
# (1000, 2)

# %%
X = df[['Number of Units']]
y = df['Manufacturing Cost']

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.20)

# %% [markdown]
# ## 1.2 Regresión Lineal.
# Realiza la regresión lineal: modelo generado (ecuación), su visualización, sus errores y r cuadrada.

# %%
sns.scatterplot(x = Xtrain['Number of Units'], y = ytrain)
plt.show()

# %% [markdown]
# Estimacion de modelo

# %%
lrm = LinearRegression()
lrm.fit(Xtrain, ytrain)
yhatTr = lrm.predict(Xtrain)
yhatTe = lrm.predict(Xtest)

# %%
lrm.coef_, lrm.intercept_
# Out:
# (array([-5.92652236]), 66.61547730029649)

# %% [markdown]
# Ecuacion de modelo generado:
#
# $\hat{y} =  -6.18X + 67.69$

# %% [markdown]
# Visualizacion

# %%
sns.scatterplot(x = Xtrain['Number of Units'], y = ytrain)
sns.scatterplot(x = Xtrain['Number of Units'], y = yhatTr)
plt.show()

# %%
sns.scatterplot(x = Xtest['Number of Units'], y = ytest)
sns.scatterplot(x = Xtest['Number of Units'], y = yhatTe)
plt.show()

# %% [markdown]
# Errores

# %%
Residuos =  ytrain - yhatTr
sns.scatterplot(x = yhatTr, y = Residuos)
plt.title('Train set')
plt.xlabel('Predicciones')
plt.ylabel('Residuos')
plt.show()

# %%
Residuos =  ytest - yhatTe
sns.scatterplot(x = yhatTe, y = Residuos)
plt.title('Test set')
plt.xlabel('Predicciones')
plt.ylabel('Residuos')
plt.show()

# %% [markdown]
# $R^2$

# %%
print('R^2 train set:', r2_score(ytrain, yhatTr))
print('R^2 test set:', r2_score(ytest, yhatTe))
# Out:
# R^2 train set: 0.5798590951289098
# R^2 test set: 0.5747310173567839

# %%
RegLinR2_tr = r2_score(ytrain, yhatTr)
RegLinR2_te = r2_score(ytest, yhatTe)
RegLinMAE_tr = mean_absolute_error(ytrain, yhatTr)
RegLinMAE_te = mean_absolute_error(ytest, yhatTe)

# %% [markdown]
# ## 1.3 Regresión Polinomial.
# Realiza la  regresión polinomial completa, tu modelo generado (ecuación), su visualización, sus errores y r cuadrada.

# %%
poly = PolynomialFeatures(degree = 5, include_bias=False)
XtrainP5 = poly.fit_transform(Xtrain)
XtestP5 = poly.fit_transform(Xtest)
XtestP5.shape
# Out:
# (200, 5)

# %%
lrm = LinearRegression()
lrm.fit(XtrainP5, ytrain)
yhatTr = lrm.predict(XtrainP5)
yhatTe = lrm.predict(XtestP5)

# %%
lrm.coef_, lrm.intercept_
# Out:
# (array([-8.39308083e+01,  2.71971069e+01, -4.66454785e+00,  3.97442155e-01,
#         -1.32196259e-02]), 151.69917925239497)

# %% [markdown]
# Ecuacion de modelo generado:
#
# $\hat{y} =  154.71 - 88.70X + 29.6x^2 - 5.18x^3 + 0.45x^4 - 0.0152x^5$

# %% [markdown]
# Visualizacion

# %%
sns.scatterplot(x = Xtrain['Number of Units'], y = ytrain)
sns.lineplot(x = Xtrain['Number of Units'], y = yhatTr, color='forestgreen', linewidth = 2.5)
plt.show()

# %%
sns.scatterplot(x = Xtest['Number of Units'], y = ytest)
sns.lineplot(x = Xtest['Number of Units'], y = yhatTe, color='forestgreen', linewidth = 2.5)
plt.show()

# %% [markdown]
# Errores

# %%
Residuos =  ytrain - yhatTr
sns.scatterplot(x = yhatTr, y = Residuos)
plt.title('Train set')
plt.xlabel('Predicciones')
plt.ylabel('Residuos')
plt.show()

# %%
Residuos =  ytest - yhatTe
sns.scatterplot(x = yhatTe, y = Residuos)
plt.title('Test set')
plt.xlabel('Predicciones')
plt.ylabel('Residuos')
plt.show()

# %% [markdown]
# $R^2$

# %%
print('R^2 train set:', r2_score(ytrain, yhatTr))
print('R^2 test set:', r2_score(ytest, yhatTe))
# Out:
# R^2 train set: 0.6857038770776518
# R^2 test set: 0.7319058429904364

# %%
RegPolyR2_tr = r2_score(ytrain, yhatTr)
RegPolyR2_te = r2_score(ytest, yhatTe)
RegPolyMAE_tr = mean_absolute_error(ytrain, yhatTr)
RegPolyMAE_te = mean_absolute_error(ytest, yhatTe)

# %% [markdown]
# ## 1.4 Realiza la regresión con Ridge y Lasso.
# Incluye la ecuación de tu modelo, visualización , errores y r cuadrada.

# %%
poly = PolynomialFeatures(degree = 5, include_bias=False)
XtrainP5 = poly.fit_transform(Xtrain)
XtestP5 = poly.fit_transform(Xtest)
XtestP5.shape
# Out:
# (200, 5)

# %% [markdown]
# Ridge

# %%
lrm = Ridge(alpha = 0.1)
lrm.fit(XtrainP5, ytrain)
yhatTr = lrm.predict(XtrainP5)
yhatTe = lrm.predict(XtestP5)

# %%
lrm.coef_, lrm.intercept_
# Out:
# (array([-4.95150984e+01,  1.14350552e+01, -1.35415307e+00,  7.44963761e-02,
#         -1.40517546e-03]), 124.66770135216689)

# %% [markdown]
# Ecuacion de modelo generado:
#
# $\hat{y} =  154.71 - 49.5X + 16.61x^2 - 1.41x^3 + 0.081x^4 - 0.001661x^5$

# %% [markdown]
# Visualizacion

# %%
sns.scatterplot(x = Xtrain['Number of Units'], y = ytrain)
sns.lineplot(x = Xtrain['Number of Units'], y = yhatTr, color='forestgreen', linewidth = 2.5)
plt.show()

# %%
sns.scatterplot(x = Xtest['Number of Units'], y = ytest)
sns.lineplot(x = Xtest['Number of Units'], y = yhatTe, color='forestgreen', linewidth = 2.5)
plt.show()

# %% [markdown]
# Errores

# %%
Residuos =  ytrain - yhatTr
sns.scatterplot(x = yhatTr, y = Residuos)
plt.title('Train set')
plt.xlabel('Predicciones')
plt.ylabel('Residuos')
plt.show()

# %%
Residuos =  ytest - yhatTe
sns.scatterplot(x = yhatTe, y = Residuos)
plt.title('Test set')
plt.xlabel('Predicciones')
plt.ylabel('Residuos')
plt.show()

# %% [markdown]
# $R^2$

# %%
print('R^2 train set:', r2_score(ytrain, yhatTr))
print('R^2 test set:', r2_score(ytest, yhatTe))
# Out:
# R^2 train set: 0.6835633545765987
# R^2 test set: 0.7255603180585697

# %%
RegRidR2_tr = r2_score(ytrain, yhatTr)
RegRidR2_te = r2_score(ytest, yhatTe)
RegRidMAE_tr = mean_absolute_error(ytrain, yhatTr)
RegRidMAE_te = mean_absolute_error(ytest, yhatTe)

# %% [markdown]
# Lasso

# %%
poly = PolynomialFeatures(degree = 5, include_bias=False)
XtrainP5 = poly.fit_transform(Xtrain)
XtestP5 = poly.fit_transform(Xtest)
XtestP5.shape
# Out:
# (200, 5)

# %%
lrm = Lasso(alpha = 0.1)
lrm.fit(XtrainP5, ytrain)
yhatTr = lrm.predict(XtrainP5)
yhatTe = lrm.predict(XtestP5)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.272e+04, tolerance: 8.824e+00
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive

# %%
lrm.coef_, lrm.intercept_
# Out:
# (array([-1.40625976e+01, -1.16437180e-02,  1.92772700e-01, -4.79028549e-03,
#         -7.48753340e-04]), 87.0947858374299)

# %% [markdown]
# Ecuacion de modelo generado:
#
# $\hat{y} =  86.26 - 13.73X - 0.043x^2 - 0.19x^3 + 0.0044x^4 - 0.0001661x^5$

# %% [markdown]
# Visualizacion

# %%
sns.scatterplot(x = Xtrain['Number of Units'], y = ytrain)
sns.lineplot(x = Xtrain['Number of Units'], y = yhatTr, color='forestgreen', linewidth = 2.5)
plt.show()

# %%
sns.scatterplot(x = Xtest['Number of Units'], y = ytest)
sns.lineplot(x = Xtest['Number of Units'], y = yhatTe, color='forestgreen', linewidth = 2.5)
plt.show()

# %% [markdown]
# Errores

# %%
Residuos =  ytrain - yhatTr
sns.scatterplot(x = yhatTr, y = Residuos)
plt.title('Train set')
plt.xlabel('Predicciones')
plt.ylabel('Residuos')
plt.show()

# %%
Residuos =  ytest - yhatTe
sns.scatterplot(x = yhatTe, y = Residuos)
plt.title('Test set')
plt.xlabel('Predicciones')
plt.ylabel('Residuos')
plt.show()

# %% [markdown]
# $R^2$

# %%
print('R^2 train set:', r2_score(ytrain, yhatTr))
print('R^2 test set:', r2_score(ytest, yhatTe))
# Out:
# R^2 train set: 0.6653801199472213
# R^2 test set: 0.6949606132428463

# %%
RegLassoR2_tr = r2_score(ytrain, yhatTr)
RegLassoR2_te = r2_score(ytest, yhatTe)
RegLassoMAE_tr = mean_absolute_error(ytrain, yhatTr)
RegLassoMAE_te = mean_absolute_error(ytest, yhatTe)

# %% [markdown]
# ## 1.5 Finalmente grafica :
# MAE (de los cuatro métodos)
# R2 (de los cuatro métodos)

# %%
GraficoR2 = {'RegLinR2_te': [RegLinR2_te],
           'RegPolyR2_te': [RegPolyR2_te],
           'RegRidR2_te': [RegRidR2_te],
           'RegLassoR2_te': [RegLassoR2_te]}
GraficoR2_Df = pd.DataFrame(GraficoR2)

GraficoMAE = {'RegLinMAE_te': [RegLinMAE_te],
           'RegPolyMAE_te': [RegPolyMAE_te],
           'RegRidMAE_te': [RegRidMAE_te],
           'RegLassoMAE_te': [RegLassoMAE_te]}
GraficoMAE_Df = pd.DataFrame(GraficoMAE)

# %%
GraficoR2_Df
# Out:
#    RegLinR2_te  RegPolyR2_te  RegRidR2_te  RegLassoR2_te
# 0     0.574731      0.731906      0.72556       0.694961

# %%
GraficoR2_Df.plot.bar()

# %%
GraficoMAE_Df
# Out:
#    RegLinMAE_te  RegPolyMAE_te  RegRidMAE_te  RegLassoMAE_te
# 0      5.097379       4.385708      4.403486        4.425566

# %%
GraficoMAE_Df.plot.bar()

# %% [markdown]
# ## 1.6 Explica tus resultados:
# Que método conviene más a la empresa, ¿por que?, ¿que porcentajes de entrenamiento y evaluación usaste?, ¿que error tienes?, ¿es bueno?, ¿cómo lo sabes?

# %% [markdown]
# Nos fijamos en la cantidad de unidades que ves el costo de producción. Según nuestros resultados, el mejor modelo es un polinomio que parece tener 5 clases, posiblemente sobreentrenado. Elegí esta potencia para mostrar cómo funciona la regularización porque la potencia más correcta es probablemente la segunda potencia. Esto está relacionado con el lazo, que demuestra la transición de 0 a coeficientes lineales y coeficientes más altos. Los resultados para el mejor modelo, lo mencioné en base a r-cuadrado porque hay poca diferencia en MAE, prefiero usar MAPE que me dice más para que los modelos sean comparables.
# Como mencioné, pensé que la estimación cuadrática era correcta y lo hice, pero por razones prácticas la usé 5 veces y fue significativamente más que lineal.

# %% [markdown]
# #Ejercicio 2
# Realiza la regresión polinomial de los siguientes datos:

# %%
df = pd.read_csv('https://raw.githubusercontent.com/marypazrf/bdd/main/kc_house_data.csv')
df.sample(10)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 18422  5153200506  20140731T000000  217000.0         3       1.00
# 18699  3031200205  20140724T000000  415000.0         5       2.75
# 3481   6625910100  20150203T000000  415000.0         3       2.25
# 9844   9552701000  20150316T000000  818000.0         4       2.25
# 1840    290000055  20140516T000000  720000.0         2       1.00
# 11044  9407001620  20140812T000000  280000.0         3       2.50
# 17480  1525079056  20140502T000000  284000.0         3       1.75
# 8316   7385310040  20140605T000000  725000.0         4       2.75
# 15815  2129700525  20141028T000000  322000.0         3       1.75
# 6857   9407110680  20141008T000000  280000.0         3       1.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 18422         1000     12000     1.0           0     0  ...      7
# 18699         2060      8906     1.0           0     0  ...      7
# 3481          2180     11100     1.0           0     0  ...      8
# 9844          2460      8001     2.0           0     0  ...      8
# 1840          2020      7200     1.0           0     3  ...      7
# 11044         1370     22326     2.0           0     0  ...      7
# 17480         1800     23103     1.0           0     0  ...      7
# 8316          2420     10962     1.0           0     0  ...      8
# 15815         1400     18002     1.0           0     0  ...      6
# 6857          1370     11400     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 18422        1000              0      1959             0    98023  47.3321
# 18699        1220            840      1978             0    98118  47.5358
# 3481         1700            480      1979             0    98056  47.5162
# 9844         2460              0      1984             0    98006  47.5480
# 1840         1700            320      1947             0    98146  47.5060
# 11044        1370              0      1993             0    98045  47.4469
# 17480        1800              0      1968             0    98014  47.6517
# 8316         1530            890      1977             0    98007  47.6218
# 15815        1400              0      1977             0    98019  47.7250
# 6857         1370              0      1980             0    98045  47.4477
#
#           long  sqft_living15  sqft_lot15
# 18422 -122.346           1490       14940
# 18699 -122.289           1840        8906
# 3481  -122.176           2350       11397
# 9844  -122.154           2460        9126
# 1840  -122.384           2020        7200
# 11044 -121.775           1580       10920
# 17480 -121.906           1410       18163
# 8316  -122.152           2620       13200
# 15815 -121.967           2240       14068
# 6857  -121.770           1390        9600
#
# [10 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %%
df = df[['price', 'bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated','sqft_living15', 'sqft_lot15']]
df.shape
# Out:
# (21613, 16)

# %%
sns.set(rc={'figure.figsize':(15,6)})
sns.heatmap(df.corr(method='pearson'), annot = True, linewidths=.5, cmap = 'BuGn')

# %%
df = df[['price', 'bedrooms', 'bathrooms', 'sqft_living',
       'floors', 'waterfront', 'view', 'grade',
      'sqft_above', 'sqft_basement', 'yr_renovated','sqft_living15']]

# %%
# df = df[['price', 'bedrooms', 'bathrooms', 'sqft_living',
#           'view', 'grade',
#        'sqft_above',  'sqft_living15']]

# %% [markdown]
# ## 1.1 Divide los datos del costo de manufactura. Utiliza la función train_test_split (viene el ejemplo al final del notebook).

# %%
X = df.drop(labels = 'price', axis = 1)
y = df['price']

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.20)

# %% [markdown]
# ## 1.2 Regresión Lineal.
# Realiza la regresión lineal: modelo generado (ecuación), su visualización, sus errores y r cuadrada.

# %% [markdown]
# Estimacion de modelo

# %%
lrm = LinearRegression()
lrm.fit(Xtrain, ytrain)
yhatTr = lrm.predict(Xtrain)
yhatTe = lrm.predict(Xtest)

# %%
lrm.coef_, lrm.intercept_
# Out:
# (array([-2.92852209e+04, -1.88302051e+04,  1.34686077e+02, -8.75126057e+03,
#          6.12152867e+05,  5.59439718e+04,  1.00411741e+05,  4.58891526e+01,
#          8.87969245e+01,  6.43035338e+01,  8.97535596e+00]),
#  -506138.95748410595)

# %% [markdown]
# Ecuacion de modelo generado:
#
# $\hat{y} =  -6.18X + 67.69$

# %% [markdown]
# Errores

# %%
Residuos =  ytrain - yhatTr
sns.scatterplot(x = yhatTr, y = Residuos)
plt.title('Train set')
plt.xlabel('Predicciones')
plt.ylabel('Residuos')
plt.show()

# %%
Residuos =  ytest - yhatTe
sns.scatterplot(x = yhatTe, y = Residuos)
plt.title('Test set')
plt.xlabel('Predicciones')
plt.ylabel('Residuos')
plt.show()

# %% [markdown]
# $R^2$

# %%
print('R^2 train set:', r2_score(ytrain, yhatTr))
print('R^2 test set:', r2_score(ytest, yhatTe))
# Out:
# R^2 train set: 0.5979997527088691
# R^2 test set: 0.614421688148644

# %%
RegLinR2_tr = r2_score(ytrain, yhatTr)
RegLinR2_te = r2_score(ytest, yhatTe)
RegLinMAE_tr = mean_absolute_error(ytrain, yhatTr)
RegLinMAE_te = mean_absolute_error(ytest, yhatTe)

# %% [markdown]
# ## 1.3 Regresión Polinomial.
# Realiza la  regresión polinomial completa, tu modelo generado (ecuación), su visualización, sus errores y r cuadrada.

# %%
poly = PolynomialFeatures(degree = 3, include_bias=False)
XtrainP5 = poly.fit_transform(Xtrain)
XtestP5 = poly.fit_transform(Xtest)
XtestP5.shape
# Out:
# (4323, 363)

# %%
lrm = LinearRegression()
lrm.fit(XtrainP5, ytrain)
yhatTr = lrm.predict(XtrainP5)
yhatTe = lrm.predict(XtestP5)

# %%
lrm.coef_, lrm.intercept_
# Out:
# (array([-3.91359905e+04,  6.55379607e+05, -1.67429553e+02,  9.37917309e+05,
#          1.03398573e+04,  2.15936810e+05, -5.39243874e+04,  2.27841315e+02,
#         -4.12663737e+02, -1.75689736e+04, -1.72617484e+00, -2.49619416e+04,
#         -3.17657531e+03,  4.17437451e+01,  2.50823197e+05,  1.84124686e+04,
#         -2.81783761e+04, -3.68116907e+04, -3.44921102e+01,  8.89193516e+01,
#         -3.09017188e+02,  2.74137257e+00, -5.76899480e+04,  1.56176882e+02,
#         -2.12699521e+05, -1.17996351e+06,  1.48016392e+05, -1.43264598e+05,
#          2.34134575e+00,  1.55540672e+02, -7.46517777e+02,  2.25792114e+01,
#          1.74048432e-01,  8.05151125e+01,  5.89414319e+02,  1.87108342e+01,
#          1.77142910e-01,  1.18151471e-01, -1.53799622e-02,  1.91983835e-01,
#          7.66943610e-01,  7.67844183e-02,  7.65909051e-03, -2.30558579e+01,
#         -7.17783209e+00,  3.98942875e-01, -3.20519329e+01,  2.36077507e+00,
#          5.51155596e-01, -2.30340327e+01,  7.05674333e+00, -5.81729873e+00,
#         -1.93189776e+01, -1.35171682e+01,  1.52101717e-01,  9.01784988e+00,
#          7.05641051e+00, -5.81733367e+00, -1.93189750e+01, -7.65544790e-03,
#          1.15748090e-03, -1.74036586e-05,  1.25525694e-05]),
#  -610323.5915493254)

# %% [markdown]
# Ecuacion de modelo generado:
#
# $\hat{y} =  154.71 - 88.70X + 29.6x^2 - 5.18x^3 + 0.45x^4 - 0.0152x^5$

# %% [markdown]
# Errores

# %%
Residuos =  ytrain - yhatTr
sns.scatterplot(x = yhatTr, y = Residuos)
plt.title('Train set')
plt.xlabel('Predicciones')
plt.ylabel('Residuos')
plt.show()

# %%
Residuos =  ytest - yhatTe
sns.scatterplot(x = yhatTe, y = Residuos)
plt.title('Test set')
plt.xlabel('Predicciones')
plt.ylabel('Residuos')
plt.show()

# %% [markdown]
# $R^2$

# %%
print('R^2 train set:', r2_score(ytrain, yhatTr))
print('R^2 test set:', r2_score(ytest, yhatTe))
# Out:
# R^2 train set: 0.7316686449702545
# R^2 test set: 0.6622242534906233

# %%
RegPolyR2_tr = r2_score(ytrain, yhatTr)
RegPolyR2_te = r2_score(ytest, yhatTe)
RegPolyMAE_tr = mean_absolute_error(ytrain, yhatTr)
RegPolyMAE_te = mean_absolute_error(ytest, yhatTe)

# %% [markdown]
# ## 1.4 Realiza la regresión con Ridge y Lasso.
# Incluye la ecuación de tu modelo, visualización , errores y r cuadrada.

# %%
poly = PolynomialFeatures(degree = 3, include_bias=False)
# XtrainP5 = poly.fit_transform(Xtrain)
# XtestP5 = poly.fit_transform(Xtest)
XtrainP5 = Xtrain
XtestP5 = Xtest
XtestP5.shape
# Out:
# (4323, 11)

# %% [markdown]
# Ridge

# %%
lrm = Ridge(alpha = 0.1)
lrm.fit(XtrainP5, ytrain)
yhatTr = lrm.predict(XtrainP5)
yhatTe = lrm.predict(XtestP5)

# %%
lrm.coef_, lrm.intercept_
# Out:
# (array([-2.92880307e+04, -1.88294325e+04,  1.34689012e+02, -8.75069756e+03,
#          6.11575207e+05,  5.59699618e+04,  1.00408582e+05,  4.58932336e+01,
#          8.87943008e+01,  6.43101425e+01,  8.97214537e+00]),
#  -506116.3609423854)

# %% [markdown]
# Ecuacion de modelo generado:
#
# $\hat{y} =  154.71 - 49.5X + 16.61x^2 - 1.41x^3 + 0.081x^4 - 0.001661x^5$

# %% [markdown]
# Errores

# %%
Residuos =  ytrain - yhatTr
sns.scatterplot(x = yhatTr, y = Residuos)
plt.title('Train set')
plt.xlabel('Predicciones')
plt.ylabel('Residuos')
plt.show()

# %%
Residuos =  ytest - yhatTe
sns.scatterplot(x = yhatTe, y = Residuos)
plt.title('Test set')
plt.xlabel('Predicciones')
plt.ylabel('Residuos')
plt.show()

# %% [markdown]
# $R^2$

# %%
print('R^2 train set:', r2_score(ytrain, yhatTr))
print('R^2 test set:', r2_score(ytest, yhatTe))
# Out:
# R^2 train set: 0.5979997378375346
# R^2 test set: 0.6144335005879769

# %%
RegRidR2_tr = r2_score(ytrain, yhatTr)
RegRidR2_te = r2_score(ytest, yhatTe)
RegRidMAE_tr = mean_absolute_error(ytrain, yhatTr)
RegRidMAE_te = mean_absolute_error(ytest, yhatTe)

# %% [markdown]
# Lasso

# %%
poly = PolynomialFeatures(degree = 5, include_bias=False)
# XtrainP5 = poly.fit_transform(Xtrain)
# XtestP5 = poly.fit_transform(Xtest)
XtrainP5 = Xtrain
XtestP5 = Xtest
XtestP5.shape
# Out:
# (4323, 11)

# %%
lrm = Lasso(alpha = 0.1)
lrm.fit(XtrainP5, ytrain)
yhatTr = lrm.predict(XtrainP5)
yhatTe = lrm.predict(XtestP5)

# %%
lrm.coef_, lrm.intercept_
# Out:
# (array([-2.92852023e+04, -1.88299173e+04,  3.02317300e+02, -8.75074807e+03,
#          6.12137248e+05,  5.59445223e+04,  1.00411386e+05, -1.21742092e+02,
#         -7.88342349e+01,  6.43037237e+01,  8.97549164e+00]),
#  -506137.95705406833)

# %% [markdown]
# Ecuacion de modelo generado:
#
# $\hat{y} =  86.26 - 13.73X - 0.043x^2 - 0.19x^3 + 0.0044x^4 - 0.0001661x^5$

# %% [markdown]
# Errores

# %%
Residuos =  ytrain - yhatTr
sns.scatterplot(x = yhatTr, y = Residuos)
plt.title('Train set')
plt.xlabel('Predicciones')
plt.ylabel('Residuos')
plt.show()

# %%
Residuos =  ytest - yhatTe
sns.scatterplot(x = yhatTe, y = Residuos)
plt.title('Test set')
plt.xlabel('Predicciones')
plt.ylabel('Residuos')
plt.show()

# %% [markdown]
# $R^2$

# %%
print('R^2 train set:', r2_score(ytrain, yhatTr))
print('R^2 test set:', r2_score(ytest, yhatTe))
# Out:
# R^2 train set: 0.5979997526970053
# R^2 test set: 0.6144219866216609

# %%
RegLassoR2_tr = r2_score(ytrain, yhatTr)
RegLassoR2_te = r2_score(ytest, yhatTe)
RegLassoMAE_tr = mean_absolute_error(ytrain, yhatTr)
RegLassoMAE_te = mean_absolute_error(ytest, yhatTe)

# %% [markdown]
# ## 1.5 Finalmente grafica :
# MAE (de los cuatro métodos)
# R2 (de los cuatro métodos)

# %%
GraficoR2 = {'RegLinR2_te': [RegLinR2_te],
           'RegPolyR2_te': [RegPolyR2_te],
           'RegRidR2_te': [RegRidR2_te],
           'RegLassoR2_te': [RegLassoR2_te]}
GraficoR2_Df = pd.DataFrame(GraficoR2)

GraficoMAE = {'RegLinMAE_te': [RegLinMAE_te],
           'RegPolyMAE_te': [RegPolyMAE_te],
           'RegRidMAE_te': [RegRidMAE_te],
           'RegLassoMAE_te': [RegLassoMAE_te]}
GraficoMAE_Df = pd.DataFrame(GraficoMAE)

# %%
GraficoR2_Df.plot.bar()

# %%
GraficoMAE_Df.plot.bar()

# %% [markdown]
# Explica tus resultados, que método se aproxima mejor, ¿por qué?, ¿qué porcentajes de entrenamiento y evaluación usaste? ¿Que error tienes?, ¿es bueno?, ¿Cómo lo sabes?
#
# Agrega las conclusiones

# %% [markdown]
# Como puede verse, las ecuaciones del modelo no se describen porque son multivariables.
# Vale la pena señalar que con lasso podemos comenzar a mostrar qué variables pueden ser importantes para el ajuste del modelo. Sin embargo, los resultados no fueron muy prometedores. Hacerlo bien el 60% de las veces puede no ser muy útil. Nuevamente, prefiero usar r al cuadrado con MAE, me dice más.
# No quiero tomar ningún modelo, de hecho me detuve para trabajar más con variables, fomentar relaciones y trabajar mejor en modelos, no se puede construir algo fuerte en horas. Intenté lo que obtuve elevando todas las variables a polinomios, pero no obtuve mejores resultados.
